# %% [markdown]
# # R3GAN
#
# By [Derrick Schultz](https://twitter.com/dvsch)
#
# No promises...

# %% [markdown]
# ## Setup

# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-b5be30c8-70f0-d32b-f7df-03a1e4cf5de5)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install gdown timm ftfy ninja imageio-ffmpeg opensimplex
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (5.2.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (1.0.15)
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting ninja
#   Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/dist-packages (0.6.0)
# Collecting opensimplex
#   Downloading opensimplex-0.4.5.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown) (4.13.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from timm) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm) (0.21.0+cu124)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from timm) (0.30.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from timm) (0.5.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from opensimplex) (2.0.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown) (4.13.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (24.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->timm)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->timm)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->timm)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->timm)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->timm)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->timm)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->timm)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->timm) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->timm) (11.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->timm) (3.0.2)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.8 MB/s eta 0:00:00
# Downloading ninja-1.11.1.4-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (422 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 31.2 MB/s eta 0:00:00
# Downloading opensimplex-0.4.5.1-py3-none-any.whl (267 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.0/268.0 kB 25.5 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 123.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 107.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 106.4 MB/s eta 0:00:00
# Installing collected packages: opensimplex, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, ninja, ftfy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed ftfy-6.3.1 ninja-1.11.1.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 opensimplex-0.4.5.1

# %%
import os
if os.path.isdir("/content/drive/MyDrive/r3gan"):
    # %cd "/content/drive/MyDrive/r3gan/R3GAN/"
elif os.path.isdir("/content/drive/"):
    #install script
    # %cd "/content/drive/MyDrive/"
    # !mkdir r3gan
    # %cd r3gan
    # !git clone https://github.com/brownvc/R3GAN/
    # %cd R3GAN
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # !wget https://huggingface.co/brownvc/R3GAN-FFHQ-256x256/resolve/main/network-snapshot-final.pkl -O ./pretrained/ffhq-256.pkl
else:
    # !git clone https://github.com/brownvc/R3GAN/
    # %cd R3GAN
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # %cd pretrained
    # !wget https://huggingface.co/brownvc/R3GAN-FFHQ-256x256/resolve/main/network-snapshot-final.pkl -O ./pretrained/ffhq-256.pkl
    # %cd ../
# Out:
# /content/drive/MyDrive/r3gan/R3GAN

# %% [markdown]
# This cell will update to the latest repo. Git and Drive/Colab don’t play as nicely as I’d like so 🤞. The other option is to delete your folder in Drive (after saving out `/results` and `/datasets`!) and running the script above to replace the entire folder.

# %%
# %cd "/content/drive/My Drive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch"
# !git config --global user.name "test"
# !git config --global user.email "test@test.com"
# !git fetch origin
# !git pull
# !git stash
# !git checkout origin/main -- train.py gen_images.py gen_video.py README.md training/training_loop.py

# %% [markdown]
# ## Convert/Create Dataset
# Pass a folder of images (just .pngs? TK) to create a zip file.

# %%
# !python dataset_tool.py --source=/content/tmp/drawn-gems-1024 --dest=./datasets/drawn-gems-1024.zip

# %% [markdown]
# ## Training
#
#
# Working Notes:

# %%
# !python train.py --help

# %%
# !python train.py --outdir=./training-runs --data=/content/drive/MyDrive/stylegan_xl/data/drawn-gems-256.zip \
--gpus=1 --batch=32 --g-batch-gpu=32 --d-batch-gpu=32 --snap=1 --mirror=1 --preset='FFHQ-256' --metrics=None \
--resume=/content/drive/MyDrive/r3gan/R3GAN/training-runs/00002-drawn-gems-256-gpus1-batch32/network-snapshot-000143870.pkl

# %% [markdown]
# ## Image Generation

# %%
# !python gen_images.py --help

# %%
# !python gen_image_debug.py --outdir=/content/drive/MyDrive/r3gan/R3GAN/generated --seeds=2-52 \
    --network=/content/drive/MyDrive/r3gan/R3GAN/training-runs/00032-carpet256_unzipped-gpus1-batch8/network-snapshot-000000034.pkl

# %% [markdown]
# ## Video Generation
# Not yet!

# %%
#script to generate looping vids
import os
import numpy as np
import torch
import PIL.Image
import dnnlib
import legacy
from tqdm import tqdm

network_pkl = "/content/drive/MyDrive/r3gan/R3GAN/training-runs/00032-carpet256_unzipped-gpus1-batch8/network-snapshot-000000035.pkl"
outdir = "/content/drive/MyDrive/r3gan/R3GAN/generated/vid16"
num_frames = 900
radius = 10.0

os.makedirs(outdir, exist_ok=True)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

with dnnlib.util.open_url(network_pkl) as f:
    G = legacy.load_network_pkl(f)["G_ema"].to(device)

print("G.z_dim =", G.z_dim)
z_dim = G.z_dim

# Create circular latent path
seed = 53241  # Change this to try different looks
rng = np.random.RandomState(seed)
z_base = rng.randn(1, z_dim)
z_dir1 = rng.randn(1, z_dim)
z_dir2 = rng.randn(1, z_dim)

z_dir1 /= np.linalg.norm(z_dir1)
z_dir2 -= z_dir1 * np.dot(z_dir1, z_dir2.T)  # orthogonalize
z_dir2 /= np.linalg.norm(z_dir2)

for frame in tqdm(range(num_frames), desc="Generating frames"):
    theta = 2 * np.pi * frame / num_frames
    z = z_base + radius * (np.cos(theta) * z_dir1 + np.sin(theta) * z_dir2)
    z_tensor = torch.from_numpy(z).to(device).to(torch.float32)

    label = torch.zeros([1, G.c_dim], device=device)
    img = G(z_tensor, label)
    img = (img.permute(0, 2, 3, 1) * 127.5 + 128).clamp(0, 255).to(torch.uint8)
    PIL.Image.fromarray(img[0].cpu().numpy(), 'RGB').save(f"{outdir}/frame_{frame:03d}.png")
# Out:
# G.z_dim = 64
# Generating frames: 100%|██████████| 900/900 [01:02<00:00, 14.42it/s]

# %%
# !ffmpeg -framerate 30 -i /content/drive/MyDrive/r3gan/R3GAN/generated/vid15/frame_%03d.png -c:v libx264 -pix_fmt yuv420p /content/drive/MyDrive/r3gan/R3GAN/generated/latent_loop/loop15.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from '/content/drive/MyDrive/r3gan/R3GAN/generated/vid15/frame_%03d.png':
#   Duration: 00:00:30.00, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 30 fps, 30 tbr, 30 tbn, 30 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x596b03c68380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x596b03c68380] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x596b03c68380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/content/drive/MyDrive/r3gan/R3GAN/generated/latent_loop/loop15.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 30 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  900 fps=340 q=-1.0 Lsize=    1183kB time=00:00:29.90 bitrate= 324.0kbits/s speed=11.3x
# video:1176kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.576635%
# [libx264 @ 0x596b03c68380] frame I:4     Avg QP:21.74  size: 13994
# [libx264 @ 0x596b03c68380] frame P:723   Avg QP:24.65  size:  1573
# [libx264 @ 0x596b03c68380] frame B:173   Avg QP:29.13  size:    60
# [libx264 @ 0x596b03c68380] consecutive B-frames: 67.0% 17.3% 14.3%  1.3%
# [libx264 @ 0x596b03c68380] mb I  I16..4:  0.6% 37.7% 61.7%
# [libx264 @ 0x596b03c68380] mb P  I16..4:  0.0%  0.1%  0.0%  P16..4: 39.3% 16.7% 17.2%  0.0%  0.0%    skip:26.6%
# [libx264 @ 0x596b03c68380] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 23.3%  0.1%  0.0%  direct: 0.1%  skip:76.5%  L0: 5.3% L1:91.6% BI: 3.1%
# [libx264 @ 0x596b03c68380] 8x8 transform intra:42.2% inter:45.1%
# [libx264 @ 0x596b03c68380] coded y,uvDC,uvAC intra: 78.0% 84.0% 63.8% inter: 29.8% 12.9% 1.8%
# [libx264 @ 0x596b03c68380] i16 v,h,dc,p: 37%  9% 51%  4%
# [libx264 @ 0x596b03c68380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25%  8% 24%  5%  7%  9%  5% 10%  7%
# [libx264 @ 0x596b03c68380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30%  9% 15%  7%  8% 12%  5%  9%  6%
# [libx264 @ 0x596b03c68380] i8c dc,h,v,p: 55% 12% 25%  9%
# [libx264 @ 0x596b03c68380] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x596b03c68380] ref P L0: 80.7% 17.0%  2.0%  0.3%
# [libx264 @ 0x596b03c68380] ref B L0: 89.0%  9.7%  1.2%
# [libx264 @ 0x596b03c68380] ref B L1: 99.8%  0.2%
# [libx264 @ 0x596b03c68380] kb/s:320.90

# %%
#!python gen_video.py --help

# %%
#!python gen_video.py --output=/content/lerp.mp4 --trunc=1 --seeds=100-124 --grid=1x1 --w-frames=72 \
    --network=/content/drive/MyDrive/colab-sg3/stylegan3/results/00014-stylegan3-r-drawn-gems-1024-gpus1-batch32-gamma10/network-snapshot-000104.pkl

# %%
# !zip -r /content/out.zip /content/out
# Out:
# 	zip warning: name not matched: /content/out
#
# zip error: Nothing to do! (try: zip -r /content/out.zip . -i /content/out)

# %%
# 🚀 Batch Generate 30-Second Latent Loop Videos — All Videos in One Folder

import os
import numpy as np
import torch
import PIL.Image
import dnnlib
import legacy
import subprocess

# ---- CONFIGURATION ----
network_pkl = "/content/drive/MyDrive/r3gan/R3GAN/training-runs/00032-carpet256_unzipped-gpus1-batch8/network-snapshot-000000035.pkl"
outdir = "/content/drive/MyDrive/r3gan/R3GAN/generated/loops"
seeds = [1000, 2000, 3000, 4000, 5000, 6000, 236471, 48592, 125364, 3289, 12673, 1, 59, 35103, 341935, 385294, 4472, 10000, 8000, 9342, 47210, 4278, 4672,
         39624, 7239, 467, 3945, 5284, 60273, 47642, 5626, 57371, 5091742, 34018, 47581, 60264, 64, 59276, 67436, 5630, 5711, 2056, 8582, 58351, 34572, 46,
         8867, 352, 8658, 456, 235, 7457, 2578, 7028, 67264, 69702, 3346, 9572, 5727, 6242, 436, 754, 2, 7, 67, 5764, 23452, 5675, 867, 304, 56658, 9874,
         5463, 35868, 3404, 3419, 459, 6784, 54057, 23478, 45346, 32842, 31878, 674, 58678, 3241, 6784, 67987, 76234, 39241, 4859, 6509, 741770, 34572, 54763,
         12419, 6381, 327491, 4603, 213618, 453491, 3289, 65401, 45728, 214436, 2347456, 56891, 978152469, 1640753622, 209005190, 768400372, 1842041602, 747234424, 222929595, 702832491, 1823931250, 1592649734, 1322570461, 1344741592, 153837313, 1017344335, 140819334, 1381701566, 1621411093, 726816702, 2049493708, 47029113, 939418723, 1345842041, 1422515812, 347635342, 1295513942, 236689735, 2102839257, 1662506407, 1699332921, 778682808, 1809148085, 579474301, 2006541608, 2110904428, 1875044436, 1215831636, 1411440862, 1526088361, 1205466405, 1803132320, 288107249, 690800585, 1233209912, 335038309, 1809788257, 219310004, 725375701, 2067318996, 1547590592, 1025898503, 1063718993, 1061629332, 1724647574, 1291755517, 1403659180, 1250849341, 1963235692, 1336553024, 1138501385, 313506228, 1516635082, 2045108185, 1286480049, 394925646, 1170623569, 1427171627, 2076931801, 145971663, 1326226850, 761591178, 1953076429, 1643976765, 1231456955, 703931825, 658070847, 681983622, 847307201, 1856892427, 1829386077, 1481597334, 1085905271, 845356707, 1168360872, 1068962125, 512235358, 2091177568, 1604878466, 108722157, 876809639, 1324976078, 1501350026, 1435904592]

# ---- REMOVE DUPLICATES + VALIDATE SEEDS ----
seeds = sorted(set(seeds))
max_seed_value = 2**31 - 1
for seed in seeds:
    if not (0 <= seed <= max_seed_value):
        raise ValueError(f"Seed {seed} is out of valid range (0 to {max_seed_value})")

num_frames = 900  # 30 seconds at 30 FPS
fps = 30
z_dim = 64  # z_dim must match your model
radius = 10.0

device = torch.device("cuda")
os.makedirs(outdir, exist_ok=True)

# ---- LOAD NETWORK ----
print(f"Loading network from {network_pkl}...")
with dnnlib.util.open_url(network_pkl) as f:
    G = legacy.load_network_pkl(f)["G_ema"].to(device)

# ---- GENERATE FOR EACH SEED ----
for seed in seeds:
    print(f"\n🔵 Generating latent loop for seed {seed}...")
    frames_dir = os.path.join(outdir, f"temp_frames_seed_{seed}")
    os.makedirs(frames_dir, exist_ok=True)

    rng = np.random.RandomState(seed)
    z_base = rng.randn(1, z_dim)
    z_dir1 = rng.randn(1, z_dim)
    z_dir2 = rng.randn(1, z_dim)
    z_dir1 /= np.linalg.norm(z_dir1)
    z_dir2 -= z_dir1 * np.dot(z_dir1, z_dir2.T)
    z_dir2 /= np.linalg.norm(z_dir2)

    label = torch.zeros([1, G.c_dim], device=device)

    for frame_idx in range(num_frames):
        theta = 2 * np.pi * frame_idx / num_frames
        z = z_base + radius * (np.cos(theta) * z_dir1 + np.sin(theta) * z_dir2)
        z_tensor = torch.from_numpy(z).to(device).to(torch.float32)

        img = G(z_tensor, label)
        img = (img.permute(0, 2, 3, 1) * 127.5 + 128).clamp(0, 255).to(torch.uint8)
        img_np = img[0].cpu().numpy()

        frame_path = os.path.join(frames_dir, f"frame_{frame_idx:04d}.png")
        PIL.Image.fromarray(img_np, 'RGB').save(frame_path)

    print(f"✅ Finished frames for seed {seed}.")

    # ---- CREATE VIDEO FROM FRAMES ----
    video_path = os.path.join(outdir, f"latent_loop_seed_{seed}.mp4")
    ffmpeg_cmd = [
        'ffmpeg',
        '-y',
        '-r', str(fps),
        '-i', os.path.join(frames_dir, 'frame_%04d.png'),
        '-c:v', 'libx264',
        '-pix_fmt', 'yuv420p',
        video_path
    ]
    print(f"🎥 Creating video for seed {seed}...")
    subprocess.run(ffmpeg_cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # ---- CLEAN UP FRAMES ----
    for frame_file in os.listdir(frames_dir):
        os.remove(os.path.join(frames_dir, frame_file))
    os.rmdir(frames_dir)

    print(f"🎬 Saved and cleaned up: {video_path}")

print("\n✨ All looping videos generated into one folder!")
# Out:
# Loading network from /content/drive/MyDrive/r3gan/R3GAN/training-runs/00032-carpet256_unzipped-gpus1-batch8/network-snapshot-000000035.pkl...
#
# 🔵 Generating latent loop for seed 1...
# ✅ Finished frames for seed 1.
# 🎥 Creating video for seed 1...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_1.mp4
#
# 🔵 Generating latent loop for seed 2...
# ✅ Finished frames for seed 2.
# 🎥 Creating video for seed 2...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_2.mp4
#
# 🔵 Generating latent loop for seed 7...
# ✅ Finished frames for seed 7.
# 🎥 Creating video for seed 7...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_7.mp4
#
# 🔵 Generating latent loop for seed 46...
# ✅ Finished frames for seed 46.
# 🎥 Creating video for seed 46...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_46.mp4
#
# 🔵 Generating latent loop for seed 59...
# ✅ Finished frames for seed 59.
# 🎥 Creating video for seed 59...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_59.mp4
#
# 🔵 Generating latent loop for seed 64...
# ✅ Finished frames for seed 64.
# 🎥 Creating video for seed 64...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_64.mp4
#
# 🔵 Generating latent loop for seed 67...
# ✅ Finished frames for seed 67.
# 🎥 Creating video for seed 67...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_67.mp4
#
# 🔵 Generating latent loop for seed 235...
# ✅ Finished frames for seed 235.
# 🎥 Creating video for seed 235...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_235.mp4
#
# 🔵 Generating latent loop for seed 304...
# ✅ Finished frames for seed 304.
# 🎥 Creating video for seed 304...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_304.mp4
#
# 🔵 Generating latent loop for seed 352...
# ✅ Finished frames for seed 352.
# 🎥 Creating video for seed 352...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_352.mp4
#
# 🔵 Generating latent loop for seed 436...
# ✅ Finished frames for seed 436.
# 🎥 Creating video for seed 436...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_436.mp4
#
# 🔵 Generating latent loop for seed 456...
# ✅ Finished frames for seed 456.
# 🎥 Creating video for seed 456...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_456.mp4
#
# 🔵 Generating latent loop for seed 459...
# ✅ Finished frames for seed 459.
# 🎥 Creating video for seed 459...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_459.mp4
#
# 🔵 Generating latent loop for seed 467...
# ✅ Finished frames for seed 467.
# 🎥 Creating video for seed 467...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_467.mp4
#
# 🔵 Generating latent loop for seed 674...
# ✅ Finished frames for seed 674.
# 🎥 Creating video for seed 674...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_674.mp4
#
# 🔵 Generating latent loop for seed 754...
# ✅ Finished frames for seed 754.
# 🎥 Creating video for seed 754...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_754.mp4
#
# 🔵 Generating latent loop for seed 867...
# ✅ Finished frames for seed 867.
# 🎥 Creating video for seed 867...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_867.mp4
#
# 🔵 Generating latent loop for seed 1000...
# ✅ Finished frames for seed 1000.
# 🎥 Creating video for seed 1000...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_1000.mp4
#
# 🔵 Generating latent loop for seed 2000...
# ✅ Finished frames for seed 2000.
# 🎥 Creating video for seed 2000...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_2000.mp4
#
# 🔵 Generating latent loop for seed 2056...
# ✅ Finished frames for seed 2056.
# 🎥 Creating video for seed 2056...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_2056.mp4
#
# 🔵 Generating latent loop for seed 2578...
# ✅ Finished frames for seed 2578.
# 🎥 Creating video for seed 2578...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_2578.mp4
#
# 🔵 Generating latent loop for seed 3000...
# ✅ Finished frames for seed 3000.
# 🎥 Creating video for seed 3000...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_3000.mp4
#
# 🔵 Generating latent loop for seed 3241...
# ✅ Finished frames for seed 3241.
# 🎥 Creating video for seed 3241...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_3241.mp4
#
# 🔵 Generating latent loop for seed 3289...
# ✅ Finished frames for seed 3289.
# 🎥 Creating video for seed 3289...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_3289.mp4
#
# 🔵 Generating latent loop for seed 3346...
# ✅ Finished frames for seed 3346.
# 🎥 Creating video for seed 3346...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_3346.mp4
#
# 🔵 Generating latent loop for seed 3404...
# ✅ Finished frames for seed 3404.
# 🎥 Creating video for seed 3404...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_3404.mp4
#
# 🔵 Generating latent loop for seed 3419...
# ✅ Finished frames for seed 3419.
# 🎥 Creating video for seed 3419...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_3419.mp4
#
# 🔵 Generating latent loop for seed 3945...
# ✅ Finished frames for seed 3945.
# 🎥 Creating video for seed 3945...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_3945.mp4
#
# 🔵 Generating latent loop for seed 4000...
# ✅ Finished frames for seed 4000.
# 🎥 Creating video for seed 4000...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_4000.mp4
#
# 🔵 Generating latent loop for seed 4278...
# ✅ Finished frames for seed 4278.
# 🎥 Creating video for seed 4278...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_4278.mp4
#
# 🔵 Generating latent loop for seed 4472...
# ✅ Finished frames for seed 4472.
# 🎥 Creating video for seed 4472...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_4472.mp4
#
# 🔵 Generating latent loop for seed 4603...
# ✅ Finished frames for seed 4603.
# 🎥 Creating video for seed 4603...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_4603.mp4
#
# 🔵 Generating latent loop for seed 4672...
# ✅ Finished frames for seed 4672.
# 🎥 Creating video for seed 4672...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_4672.mp4
#
# 🔵 Generating latent loop for seed 4859...
# ✅ Finished frames for seed 4859.
# 🎥 Creating video for seed 4859...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_4859.mp4
#
# 🔵 Generating latent loop for seed 5000...
# ✅ Finished frames for seed 5000.
# 🎥 Creating video for seed 5000...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_5000.mp4
#
# 🔵 Generating latent loop for seed 5284...
# ✅ Finished frames for seed 5284.
# 🎥 Creating video for seed 5284...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_5284.mp4
#
# 🔵 Generating latent loop for seed 5463...
# ✅ Finished frames for seed 5463.
# 🎥 Creating video for seed 5463...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_5463.mp4
#
# 🔵 Generating latent loop for seed 5626...
# ✅ Finished frames for seed 5626.
# 🎥 Creating video for seed 5626...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_5626.mp4
#
# 🔵 Generating latent loop for seed 5630...
# ✅ Finished frames for seed 5630.
# 🎥 Creating video for seed 5630...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_5630.mp4
#
# 🔵 Generating latent loop for seed 5675...
# ✅ Finished frames for seed 5675.
# 🎥 Creating video for seed 5675...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_5675.mp4
#
# 🔵 Generating latent loop for seed 5711...
# ✅ Finished frames for seed 5711.
# 🎥 Creating video for seed 5711...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_5711.mp4
#
# 🔵 Generating latent loop for seed 5727...
# ✅ Finished frames for seed 5727.
# 🎥 Creating video for seed 5727...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_5727.mp4
#
# 🔵 Generating latent loop for seed 5764...
# ✅ Finished frames for seed 5764.
# 🎥 Creating video for seed 5764...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_5764.mp4
#
# 🔵 Generating latent loop for seed 6000...
# ✅ Finished frames for seed 6000.
# 🎥 Creating video for seed 6000...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_6000.mp4
#
# 🔵 Generating latent loop for seed 6242...
# ✅ Finished frames for seed 6242.
# 🎥 Creating video for seed 6242...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_6242.mp4
#
# 🔵 Generating latent loop for seed 6381...
# ✅ Finished frames for seed 6381.
# 🎥 Creating video for seed 6381...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_6381.mp4
#
# 🔵 Generating latent loop for seed 6509...
# ✅ Finished frames for seed 6509.
# 🎥 Creating video for seed 6509...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_6509.mp4
#
# 🔵 Generating latent loop for seed 6784...
# ✅ Finished frames for seed 6784.
# 🎥 Creating video for seed 6784...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_6784.mp4
#
# 🔵 Generating latent loop for seed 7028...
# ✅ Finished frames for seed 7028.
# 🎥 Creating video for seed 7028...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_7028.mp4
#
# 🔵 Generating latent loop for seed 7239...
# ✅ Finished frames for seed 7239.
# 🎥 Creating video for seed 7239...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_7239.mp4
#
# 🔵 Generating latent loop for seed 7457...
# ✅ Finished frames for seed 7457.
# 🎥 Creating video for seed 7457...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_7457.mp4
#
# 🔵 Generating latent loop for seed 8000...
# ✅ Finished frames for seed 8000.
# 🎥 Creating video for seed 8000...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_8000.mp4
#
# 🔵 Generating latent loop for seed 8582...
# ✅ Finished frames for seed 8582.
# 🎥 Creating video for seed 8582...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_8582.mp4
#
# 🔵 Generating latent loop for seed 8658...
# ✅ Finished frames for seed 8658.
# 🎥 Creating video for seed 8658...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_8658.mp4
#
# 🔵 Generating latent loop for seed 8867...
# ✅ Finished frames for seed 8867.
# 🎥 Creating video for seed 8867...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_8867.mp4
#
# 🔵 Generating latent loop for seed 9342...
# ✅ Finished frames for seed 9342.
# 🎥 Creating video for seed 9342...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_9342.mp4
#
# 🔵 Generating latent loop for seed 9572...
# ✅ Finished frames for seed 9572.
# 🎥 Creating video for seed 9572...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_9572.mp4
#
# 🔵 Generating latent loop for seed 9874...
# ✅ Finished frames for seed 9874.
# 🎥 Creating video for seed 9874...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_9874.mp4
#
# 🔵 Generating latent loop for seed 10000...
# ✅ Finished frames for seed 10000.
# 🎥 Creating video for seed 10000...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_10000.mp4
#
# 🔵 Generating latent loop for seed 12419...
# ✅ Finished frames for seed 12419.
# 🎥 Creating video for seed 12419...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_12419.mp4
#
# 🔵 Generating latent loop for seed 12673...
# ✅ Finished frames for seed 12673.
# 🎥 Creating video for seed 12673...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_12673.mp4
#
# 🔵 Generating latent loop for seed 23452...
# ✅ Finished frames for seed 23452.
# 🎥 Creating video for seed 23452...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_23452.mp4
#
# 🔵 Generating latent loop for seed 23478...
# ✅ Finished frames for seed 23478.
# 🎥 Creating video for seed 23478...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_23478.mp4
#
# 🔵 Generating latent loop for seed 31878...
# ✅ Finished frames for seed 31878.
# 🎥 Creating video for seed 31878...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_31878.mp4
#
# 🔵 Generating latent loop for seed 32842...
# ✅ Finished frames for seed 32842.
# 🎥 Creating video for seed 32842...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_32842.mp4
#
# 🔵 Generating latent loop for seed 34018...
# ✅ Finished frames for seed 34018.
# 🎥 Creating video for seed 34018...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_34018.mp4
#
# 🔵 Generating latent loop for seed 34572...
# ✅ Finished frames for seed 34572.
# 🎥 Creating video for seed 34572...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_34572.mp4
#
# 🔵 Generating latent loop for seed 35103...
# ✅ Finished frames for seed 35103.
# 🎥 Creating video for seed 35103...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_35103.mp4
#
# 🔵 Generating latent loop for seed 35868...
# ✅ Finished frames for seed 35868.
# 🎥 Creating video for seed 35868...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_35868.mp4
#
# 🔵 Generating latent loop for seed 39241...
# ✅ Finished frames for seed 39241.
# 🎥 Creating video for seed 39241...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_39241.mp4
#
# 🔵 Generating latent loop for seed 39624...
# ✅ Finished frames for seed 39624.
# 🎥 Creating video for seed 39624...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_39624.mp4
#
# 🔵 Generating latent loop for seed 45346...
# ✅ Finished frames for seed 45346.
# 🎥 Creating video for seed 45346...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_45346.mp4
#
# 🔵 Generating latent loop for seed 45728...
# ✅ Finished frames for seed 45728.
# 🎥 Creating video for seed 45728...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_45728.mp4
#
# 🔵 Generating latent loop for seed 47210...
# ✅ Finished frames for seed 47210.
# 🎥 Creating video for seed 47210...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_47210.mp4
#
# 🔵 Generating latent loop for seed 47581...
# ✅ Finished frames for seed 47581.
# 🎥 Creating video for seed 47581...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_47581.mp4
#
# 🔵 Generating latent loop for seed 47642...
# ✅ Finished frames for seed 47642.
# 🎥 Creating video for seed 47642...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_47642.mp4
#
# 🔵 Generating latent loop for seed 48592...
# ✅ Finished frames for seed 48592.
# 🎥 Creating video for seed 48592...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_48592.mp4
#
# 🔵 Generating latent loop for seed 54057...
# ✅ Finished frames for seed 54057.
# 🎥 Creating video for seed 54057...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_54057.mp4
#
# 🔵 Generating latent loop for seed 54763...
# ✅ Finished frames for seed 54763.
# 🎥 Creating video for seed 54763...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_54763.mp4
#
# 🔵 Generating latent loop for seed 56658...
# ✅ Finished frames for seed 56658.
# 🎥 Creating video for seed 56658...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_56658.mp4
#
# 🔵 Generating latent loop for seed 56891...
# ✅ Finished frames for seed 56891.
# 🎥 Creating video for seed 56891...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_56891.mp4
#
# 🔵 Generating latent loop for seed 57371...
# ✅ Finished frames for seed 57371.
# 🎥 Creating video for seed 57371...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_57371.mp4
#
# 🔵 Generating latent loop for seed 58351...
# ✅ Finished frames for seed 58351.
# 🎥 Creating video for seed 58351...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_58351.mp4
#
# 🔵 Generating latent loop for seed 58678...
# ✅ Finished frames for seed 58678.
# 🎥 Creating video for seed 58678...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_58678.mp4
#
# 🔵 Generating latent loop for seed 59276...
# ✅ Finished frames for seed 59276.
# 🎥 Creating video for seed 59276...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_59276.mp4
#
# 🔵 Generating latent loop for seed 60264...
# ✅ Finished frames for seed 60264.
# 🎥 Creating video for seed 60264...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_60264.mp4
#
# 🔵 Generating latent loop for seed 60273...
# ✅ Finished frames for seed 60273.
# 🎥 Creating video for seed 60273...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_60273.mp4
#
# 🔵 Generating latent loop for seed 65401...
# ✅ Finished frames for seed 65401.
# 🎥 Creating video for seed 65401...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_65401.mp4
#
# 🔵 Generating latent loop for seed 67264...
# ✅ Finished frames for seed 67264.
# 🎥 Creating video for seed 67264...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_67264.mp4
#
# 🔵 Generating latent loop for seed 67436...
# ✅ Finished frames for seed 67436.
# 🎥 Creating video for seed 67436...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_67436.mp4
#
# 🔵 Generating latent loop for seed 67987...
# ✅ Finished frames for seed 67987.
# 🎥 Creating video for seed 67987...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_67987.mp4
#
# 🔵 Generating latent loop for seed 69702...
# ✅ Finished frames for seed 69702.
# 🎥 Creating video for seed 69702...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_69702.mp4
#
# 🔵 Generating latent loop for seed 76234...
# ✅ Finished frames for seed 76234.
# 🎥 Creating video for seed 76234...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_76234.mp4
#
# 🔵 Generating latent loop for seed 125364...
# ✅ Finished frames for seed 125364.
# 🎥 Creating video for seed 125364...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_125364.mp4
#
# 🔵 Generating latent loop for seed 213618...
# ✅ Finished frames for seed 213618.
# 🎥 Creating video for seed 213618...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_213618.mp4
#
# 🔵 Generating latent loop for seed 214436...
# ✅ Finished frames for seed 214436.
# 🎥 Creating video for seed 214436...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_214436.mp4
#
# 🔵 Generating latent loop for seed 236471...
# ✅ Finished frames for seed 236471.
# 🎥 Creating video for seed 236471...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_236471.mp4
#
# 🔵 Generating latent loop for seed 327491...
# ✅ Finished frames for seed 327491.
# 🎥 Creating video for seed 327491...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_327491.mp4
#
# 🔵 Generating latent loop for seed 341935...
# ✅ Finished frames for seed 341935.
# 🎥 Creating video for seed 341935...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_341935.mp4
#
# 🔵 Generating latent loop for seed 385294...
# ✅ Finished frames for seed 385294.
# 🎥 Creating video for seed 385294...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_385294.mp4
#
# 🔵 Generating latent loop for seed 453491...
# ✅ Finished frames for seed 453491.
# 🎥 Creating video for seed 453491...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_453491.mp4
#
# 🔵 Generating latent loop for seed 741770...
# ✅ Finished frames for seed 741770.
# 🎥 Creating video for seed 741770...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_741770.mp4
#
# 🔵 Generating latent loop for seed 2347456...
# ✅ Finished frames for seed 2347456.
# 🎥 Creating video for seed 2347456...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_2347456.mp4
#
# 🔵 Generating latent loop for seed 5091742...
# ✅ Finished frames for seed 5091742.
# 🎥 Creating video for seed 5091742...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_5091742.mp4
#
# 🔵 Generating latent loop for seed 47029113...
# ✅ Finished frames for seed 47029113.
# 🎥 Creating video for seed 47029113...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_47029113.mp4
#
# 🔵 Generating latent loop for seed 108722157...
# ✅ Finished frames for seed 108722157.
# 🎥 Creating video for seed 108722157...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_108722157.mp4
#
# 🔵 Generating latent loop for seed 140819334...
# ✅ Finished frames for seed 140819334.
# 🎥 Creating video for seed 140819334...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_140819334.mp4
#
# 🔵 Generating latent loop for seed 145971663...
# ✅ Finished frames for seed 145971663.
# 🎥 Creating video for seed 145971663...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_145971663.mp4
#
# 🔵 Generating latent loop for seed 153837313...
# ✅ Finished frames for seed 153837313.
# 🎥 Creating video for seed 153837313...
# 🎬 Saved and cleaned up: /content/drive/MyDrive/r3gan/R3GAN/generated/loops/latent_loop_seed_153837313.mp4
#
# 🔵 Generating latent loop for seed 209005190...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-78e459915f88> in <cell line: 0>()
#      59         z_tensor = torch.from_numpy(z).to(device).to(torch.float32)
#      60
# ---> 61         img = G(z_tensor, label)
#      62         img = (img.permute(0, 2, 3, 1) * 127.5 + 128).clamp(0, 255).to(torch.uint8)
#      63         img_np = img[0].cpu().numpy()
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /content/drive/MyDrive/r3gan/R3GAN/training/networks.py in forward(self, x, c)
#      25
#      26     def forward(self, x, c):
# ---> 27         return self.Model(x, c)
#      28
#      29 class Discriminator(nn.Module):
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /content/drive/MyDrive/r3gan/R3GAN/R3GAN/Networks.py in forward(self, x, y)
#     146
#     147         for Layer in self.MainLayers:
# --> 148             x = Layer(x)
#     149
#     150         return self.AggregationLayer(x)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /content/drive/MyDrive/r3gan/R3GAN/R3GAN/Networks.py in forward(self, x)
#     108
#     109         for Layer in self.Layers:
# --> 110             x = Layer(x)
#     111
#     112         return x
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /content/drive/MyDrive/r3gan/R3GAN/R3GAN/Networks.py in forward(self, x)
#      40     def forward(self, x):
#      41         y = self.LinearLayer1(x)
# ---> 42         y = self.LinearLayer2(self.NonLinearity1(y))
#      43         y = self.LinearLayer3(self.NonLinearity2(y))
#      44
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /content/drive/MyDrive/r3gan/R3GAN/R3GAN/Networks.py in forward(self, x)
#      21
#      22     def forward(self, x):
# ---> 23         return nn.functional.conv2d(x, self.Layer.weight.to(x.dtype), padding=self.Layer.padding, groups=self.Layer.groups)
#      24
#      25 class ResidualBlock(nn.Module):
#
# KeyboardInterrupt:

# %%
import os
import cv2  # OpenCV for reading frames
from pathlib import Path
from tqdm import tqdm  # Progress bar

# ---- CONFIGURATION ----
input_folder = "/content/drive/MyDrive/r3gan/R3GAN/generated/loops"  # Change this to where your videos/GIFs are
output_folder = "/content/drive/MyDrive/r3gan/R3GAN/generated/first_frames"  # Where first frames will be saved
allowed_extensions = ['.mp4', '.gif']  # File types to process

os.makedirs(output_folder, exist_ok=True)

# ---- PROCESS EACH VIDEO/GIF ----
input_folder = Path(input_folder)
video_files = [f for f in input_folder.rglob('*') if f.suffix.lower() in allowed_extensions]

print(f"Found {len(video_files)} videos/gifs.")

for vid_path in tqdm(video_files, desc="Extracting first frames"):
    cap = cv2.VideoCapture(str(vid_path))
    success, frame = cap.read()
    if success:
        # Save frame as PNG
        base_name = vid_path.stem  # filename without extension
        out_path = os.path.join(output_folder, f"{base_name}_firstframe.png")
        cv2.imwrite(out_path, frame)
    cap.release()

print(f"✅ Done! First frames saved to: {output_folder}")
# Out:
# Found 109 videos/gifs.
# Extracting first frames: 100%|██████████| 109/109 [00:01<00:00, 55.04it/s]
# ✅ Done! First frames saved to: /content/drive/MyDrive/r3gan/R3GAN/generated/first_frames

# %%
import os
import glob
import cv2
import PIL.Image

# ---- CONFIGURATION ----
video_folder = "/content/drive/MyDrive/r3gan/R3GAN/generated/loops"  # Where your videos/gifs are
output_folder = "/content/drive/MyDrive/r3gan/R3GAN/first_frames"     # Where extracted frames will go

os.makedirs(output_folder, exist_ok=True)

# ---- FIND ALL VIDEOS ----
video_files = glob.glob(os.path.join(video_folder, "**/*.mp4"), recursive=True)
video_files += glob.glob(os.path.join(video_folder, "**/*.gif"), recursive=True)

print(f"Found {len(video_files)} videos.")

# ---- EXTRACT FIRST FRAME ----
for vid_path in video_files:
    # Open video or gif
    cap = cv2.VideoCapture(vid_path)
    success, frame = cap.read()

    if success:
        # Convert BGR to RGB
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        # Save as PNG
        vid_name = os.path.splitext(os.path.basename(vid_path))[0]
        frame_path = os.path.join(output_folder, f"{vid_name}_firstframe.png")
        PIL.Image.fromarray(frame).save(frame_path)
        print(f"✅ Saved first frame for {vid_name}")
    else:
        print(f"⚠️ Failed to read {vid_path}")

    cap.release()

print("\n🎉 Done extracting first frames!")
# Out:
# Found 109 videos.
# ✅ Saved first frame for latent_loop_seed_1
# ✅ Saved first frame for latent_loop_seed_2
# ✅ Saved first frame for latent_loop_seed_7
# ✅ Saved first frame for latent_loop_seed_46
# ✅ Saved first frame for latent_loop_seed_59
# ✅ Saved first frame for latent_loop_seed_64
# ✅ Saved first frame for latent_loop_seed_67
# ✅ Saved first frame for latent_loop_seed_235
# ✅ Saved first frame for latent_loop_seed_304
# ✅ Saved first frame for latent_loop_seed_352
# ✅ Saved first frame for latent_loop_seed_436
# ✅ Saved first frame for latent_loop_seed_456
# ✅ Saved first frame for latent_loop_seed_459
# ✅ Saved first frame for latent_loop_seed_467
# ✅ Saved first frame for latent_loop_seed_674
# ✅ Saved first frame for latent_loop_seed_754
# ✅ Saved first frame for latent_loop_seed_867
# ✅ Saved first frame for latent_loop_seed_1000
# ✅ Saved first frame for latent_loop_seed_2000
# ✅ Saved first frame for latent_loop_seed_2056
# ✅ Saved first frame for latent_loop_seed_2578
# ✅ Saved first frame for latent_loop_seed_3000
# ✅ Saved first frame for latent_loop_seed_3241
# ✅ Saved first frame for latent_loop_seed_3289
# ✅ Saved first frame for latent_loop_seed_3346
# ✅ Saved first frame for latent_loop_seed_3404
# ✅ Saved first frame for latent_loop_seed_3419
# ✅ Saved first frame for latent_loop_seed_3945
# ✅ Saved first frame for latent_loop_seed_4000
# ✅ Saved first frame for latent_loop_seed_4278
# ✅ Saved first frame for latent_loop_seed_4472
# ✅ Saved first frame for latent_loop_seed_4603
# ✅ Saved first frame for latent_loop_seed_4672
# ✅ Saved first frame for latent_loop_seed_4859
# ✅ Saved first frame for latent_loop_seed_5000
# ✅ Saved first frame for latent_loop_seed_5284
# ✅ Saved first frame for latent_loop_seed_5463
# ✅ Saved first frame for latent_loop_seed_5626
# ✅ Saved first frame for latent_loop_seed_5630
# ✅ Saved first frame for latent_loop_seed_5675
# ✅ Saved first frame for latent_loop_seed_5711
# ✅ Saved first frame for latent_loop_seed_5727
# ✅ Saved first frame for latent_loop_seed_5764
# ✅ Saved first frame for latent_loop_seed_6000
# ✅ Saved first frame for latent_loop_seed_6242
# ✅ Saved first frame for latent_loop_seed_6381
# ✅ Saved first frame for latent_loop_seed_6509
# ✅ Saved first frame for latent_loop_seed_6784
# ✅ Saved first frame for latent_loop_seed_7028
# ✅ Saved first frame for latent_loop_seed_7239
# ✅ Saved first frame for latent_loop_seed_7457
# ✅ Saved first frame for latent_loop_seed_8000
# ✅ Saved first frame for latent_loop_seed_8582
# ✅ Saved first frame for latent_loop_seed_8658
# ✅ Saved first frame for latent_loop_seed_8867
# ✅ Saved first frame for latent_loop_seed_9342
# ✅ Saved first frame for latent_loop_seed_9572
# ✅ Saved first frame for latent_loop_seed_9874
# ✅ Saved first frame for latent_loop_seed_10000
# ✅ Saved first frame for latent_loop_seed_12419
# ✅ Saved first frame for latent_loop_seed_12673
# ✅ Saved first frame for latent_loop_seed_23452
# ✅ Saved first frame for latent_loop_seed_23478
# ✅ Saved first frame for latent_loop_seed_31878
# ✅ Saved first frame for latent_loop_seed_32842
# ✅ Saved first frame for latent_loop_seed_34018
# ✅ Saved first frame for latent_loop_seed_34572
# ✅ Saved first frame for latent_loop_seed_35103
# ✅ Saved first frame for latent_loop_seed_35868
# ✅ Saved first frame for latent_loop_seed_39241
# ✅ Saved first frame for latent_loop_seed_39624
# ✅ Saved first frame for latent_loop_seed_45346
# ✅ Saved first frame for latent_loop_seed_45728
# ✅ Saved first frame for latent_loop_seed_47210
# ✅ Saved first frame for latent_loop_seed_47581
# ✅ Saved first frame for latent_loop_seed_47642
# ✅ Saved first frame for latent_loop_seed_48592
# ✅ Saved first frame for latent_loop_seed_54057
# ✅ Saved first frame for latent_loop_seed_54763
# ✅ Saved first frame for latent_loop_seed_56658
# ✅ Saved first frame for latent_loop_seed_56891
# ✅ Saved first frame for latent_loop_seed_57371
# ✅ Saved first frame for latent_loop_seed_58351
# ✅ Saved first frame for latent_loop_seed_58678
# ✅ Saved first frame for latent_loop_seed_59276
# ✅ Saved first frame for latent_loop_seed_60264
# ✅ Saved first frame for latent_loop_seed_60273
# ✅ Saved first frame for latent_loop_seed_65401
# ✅ Saved first frame for latent_loop_seed_67264
# ✅ Saved first frame for latent_loop_seed_67436
# ✅ Saved first frame for latent_loop_seed_67987
# ✅ Saved first frame for latent_loop_seed_69702
# ✅ Saved first frame for latent_loop_seed_76234
# ✅ Saved first frame for latent_loop_seed_125364
# ✅ Saved first frame for latent_loop_seed_213618
# ✅ Saved first frame for latent_loop_seed_214436
# ✅ Saved first frame for latent_loop_seed_236471
# ✅ Saved first frame for latent_loop_seed_327491
# ✅ Saved first frame for latent_loop_seed_341935
# ✅ Saved first frame for latent_loop_seed_385294
# ✅ Saved first frame for latent_loop_seed_453491
# ✅ Saved first frame for latent_loop_seed_741770
# ✅ Saved first frame for latent_loop_seed_2347456
# ✅ Saved first frame for latent_loop_seed_5091742
# ✅ Saved first frame for latent_loop_seed_47029113
# ✅ Saved first frame for latent_loop_seed_108722157
# ✅ Saved first frame for latent_loop_seed_140819334
# ✅ Saved first frame for latent_loop_seed_145971663
# ✅ Saved first frame for latent_loop_seed_153837313
#
# 🎉 Done extracting first frames!
